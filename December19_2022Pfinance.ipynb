# %% [markdown]
# <a href="https://colab.research.google.com/github/thunde7226/CapstoneGoogleCyclist_Project/blob/main/December19_2022Pfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Using yfinance as yf
# !pip install yfinance
import yfinance as yf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 50 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 112 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 128 kB 64.2 MB/s
# ...
#      |████████████████████████████████| 110 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 47.1 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.3 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import yfinance as yf

#get stock info
appl = yf.Ticker("appl")

# %%
#get historical market data
hist = appl.history(period="max")

#show actions (dividends, splits)
appl.actions  

#show dividends
appl.dividends
# Out:
# APPL: 1d data not available for startTime=-2208994789 and endTime=1671492785. Only 100 years worth of day granularity data are allowed to be fetched per request.
# APPL: 1d data not available for startTime=-2208994789 and endTime=1671492785. Only 100 years worth of day granularity data are allowed to be fetched per request.
# APPL: 1d data not available for startTime=-2208994789 and endTime=1671492785. Only 100 years worth of day granularity data are allowed to be fetched per request.
# []

# %%
goog = yf.Ticker("goog")

#get stock info
goog.info 

#get historical market data
hist = goog.history(period="max")

#show actions (dividends, splits)
goog.actions  

#show dividends
goog.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
#show financials
goog.financials
goog.quarterly_financials

#show major holders

goog.major_holders  

#show balance sheet
goog.balance_sheet
goog.quarterly_balancesheet

#show cashflow
goog.cashflow
goog.quarterly_cashflow
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-62c9de3906ea> in <module>
#       1 #show financials
# ----> 2 goog.financials
#       3 goog.quarterly_financials
#       4
#       5 #show major holders
#
# AttributeError: 'Ticker' object has no attribute 'financials'

# %%
goog.quarterly_cashflow
# Out:
#                                                    2022-09-30     2022-06-30  \
# Operating Cash Flow                             23353000000.0  19422000000.0
# Cash Flow From Continuing Operating Activities  23353000000.0  19422000000.0
# Net Income From Continuing Operations           13910000000.0  16002000000.0
# Operating Gains Losses                           1378000000.0   1041000000.0
# Gain Loss On Investment Securities               1378000000.0   1041000000.0
# Depreciation Amortization Depletion              4046000000.0   3899000000.0
# Depreciation And Amortization                    4046000000.0   3899000000.0
# Depreciation                                     3933000000.0   3698000000.0
# Amortization Cash Flow                            113000000.0    201000000.0
# Amortization Of Intangibles                       113000000.0    201000000.0
# Deferred Tax                                    -1920000000.0  -2147000000.0
# ...

# %%
goog.recommendations
# Out:
#                                          Firm    To Grade From Grade Action
# Date
# 2012-03-14 15:28:00                Oxen Group        Hold              init
# 2012-03-28 06:29:00                 Citigroup         Buy              main
# 2012-04-03 08:45:00  Global Equities Research  Overweight              main
# 2012-04-05 06:34:00             Deutsche Bank         Buy              main
# 2012-04-09 06:03:00          Pivotal Research         Buy              main
# ...                                       ...         ...        ...    ...
# 2022-10-26 11:24:15             Raymond James  Outperform              main
# 2022-10-26 12:01:21               Cowen & Co.  Outperform              main
# 2022-10-26 12:05:10             Deutsche Bank         Buy              main
# 2022-10-26 12:12:24               Oppenheimer  Outperform              main
# 2022-11-30 11:08:27          Societe Generale         Buy              main
#
# [267 rows x 4 columns]

# %%
goog.calendar
# Out:
#                                     0                    1
# Earnings Date     2023-01-30 21:00:00  2023-02-03 21:00:00
# Earnings Average                 1.21                 1.21
# Earnings Low                     0.96                 0.96
# Earnings High                    1.38                 1.38
# Revenue Average           76786000000          76786000000
# Revenue Low               72291000000          72291000000
# Revenue High              79192000000          79192000000

# %%
#get option chain for specific expiration
opt = goog.option_chain('2022-12-23')

# %%
import yfinance as yf
data = yf.download("TSLA GOOG", start="2020-09-01", end= "2021-03-01")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data = yf.download("AMZN GOOG META", start="2021-05-01", end="2021-07-17")
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#              Adj Close                               Close              \
#                   AMZN        GOOG        META        AMZN        GOOG
# Date
# 2021-05-03  169.324493  119.758499  322.579987  169.324493  119.758499
# 2021-05-04  165.593506  117.712502  318.359985  165.593506  117.712502
# 2021-05-05  163.526993  117.836998  315.019989  163.526993  117.836998
# 2021-05-06  165.318497  119.067497  320.019989  165.318497  119.067497
# 2021-05-07  164.580505  119.934502  319.079987  164.580505  119.934502
# 2021-05-10  159.524506  117.083000  305.970001  159.524506  117.083000
# 2021-05-11  161.195496  115.438004  306.529999  161.195496  115.438004
# 2021-05-12  157.597000  111.954002  302.549988  157.597000  111.954002
# 2021-05-13  158.073502  113.098503  305.260010  158.073502  113.098503
# 2021-05-14  161.145004  115.807999  315.940002  161.145004  115.807999
# ...

# %%
data = yf.download("AMZN GOOG TSLA", start="2018-05-01", end="2018-09-15", group_by='tickers')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                  GOOG                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-05-01  50.682999  51.923500  50.410500  51.865501  51.865501  28558000
# 2018-05-02  51.404999  52.019451  51.143501  51.219002  51.219002  32062000
# 2018-05-03  50.950001  51.483749  50.314499  51.186001  51.186001  36302000
# 2018-05-04  50.845001  52.425499  50.845001  52.410500  52.410500  38774000
# 2018-05-07  52.461498  53.084000  52.355000  52.739498  52.739498  29322000
# ...               ...        ...        ...        ...        ...       ...
# 2018-09-10  58.609501  58.727001  58.005501  58.231998  58.231998  22308000
# 2018-09-11  58.081501  58.933998  57.812000  58.868000  58.868000  24186000
# 2018-09-12  58.636002  58.930500  57.917999  58.140999  58.140999  25910000
# ...
